# %% [markdown]
# # Prac 08.2
#
# In this homework we will be working with the Fashion MNIST dataset. You will be given a classifier which suffers from considerable overfitting. Your objective will be to employ regularization techniques to mitigate the overfitting problem.
#
# Let's start with the usual imports.

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, Dense, Dropout, Flatten, Input, MaxPooling2D, BatchNormalization
from tensorflow.keras import Model
from time import time

from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [15, 10]

# Set the seeds for reproducibility
from numpy.random import seed
from tensorflow.random import set_seed
seed_value = 1234578790
seed(seed_value)
set_seed(seed_value)

# %% [markdown]
# ### Dataset
#
# The MNIST fashgion dataset [link](https://github.com/zalandoresearch/fashion-mnist) was build by Zalando Reasearch tem consists of monochrome images of different type of clothing, namely:
# * 0	T-shirt/top
# * 1	Trouser
# * 2	Pullover
# * 3	Dress
# * 4	Coat
# * 5	Sandal
# * 6	Shirt
# * 7	Sneaker
# * 8	Bag
# * 9	Ankle boot
#
# It is also one of the Keras built-in datasets. Let's load the images and quickly inspect it.

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

# Dataset params
num_classes = 10
size = x_train.shape[1]

print('Train set:   ', len(y_train), 'samples')
print('Test set:    ', len(y_test), 'samples')
print('Sample dims: ', x_train.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Train set:    60000 samples
# Test set:     10000 samples
# Sample dims:  (60000, 28, 28)

# %% [markdown]
# Let's visualise some random samples.

# %%
cnt = 1
for r in range(3):
    for c in range(6):
        idx = np.random.randint(len(x_train))
        plt.subplot(3,6,cnt)
        plt.imshow(x_train[idx, ...], cmap='gray')
        plt.title(y_train[idx])
        cnt = cnt + 1

# %% [markdown]
# ### Building the Classifier
#
# We are now going to build the baseline classifier that you will use throughout this homework.

# %%
# Data normalization
x_train = x_train/255
x_test = x_test/255

# %%
inputs = Input(shape=(28, 28, 1))
net = Conv2D(32, kernel_size=(3, 3), activation="relu", padding='same')(inputs)
net = Flatten()(net)
net = Dense(128)(net)
outputs = Dense(10, activation="softmax")(net)

model = Model(inputs, outputs)
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 28, 28, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │     3,211,392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,213,002 (12.26 MB)
#  Trainable params: 3,213,002 (12.26 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
epochs = 50
batch_size = 64

model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 73s 77ms/step - accuracy: 0.7438 - loss: 0.7357 - val_accuracy: 0.8010 - val_loss: 0.5543
# Epoch 2/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 71s 75ms/step - accuracy: 0.8220 - loss: 0.5004 - val_accuracy: 0.8211 - val_loss: 0.5104
# Epoch 3/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 81s 75ms/step - accuracy: 0.8368 - loss: 0.4627 - val_accuracy: 0.8304 - val_loss: 0.4829
# Epoch 4/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 73s 78ms/step - accuracy: 0.8449 - loss: 0.4392 - val_accuracy: 0.8387 - val_loss: 0.4613
# Epoch 5/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 71s 76ms/step - accuracy: 0.8513 - loss: 0.4212 - val_accuracy: 0.8456 - val_loss: 0.4444
# Epoch 6/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 84s 78ms/step - accuracy: 0.8564 - loss: 0.4059 - val_accuracy: 0.8496 - val_loss: 0.4325
# Epoch 7/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 72s 77ms/step - accuracy: 0.8607 - loss: 0.3927 - val_accuracy: 0.8503 - val_loss: 0.4279
# Epoch 8/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 70s 75ms/step - accuracy: 0.8636 - loss: 0.3832 - val_accuracy: 0.8548 - val_loss: 0.4174
# Epoch 9/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 85s 77ms/step - accuracy: 0.8667 - loss: 0.3746 - val_accuracy: 0.8577 - val_loss: 0.4087
# Epoch 10/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 73s 77ms/step - accuracy: 0.8687 - loss: 0.3677 - val_accuracy: 0.8583 - val_loss: 0.4061
# Epoch 11/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 73s 77ms/step - accuracy: 0.8709 - loss: 0.3609 - val_accuracy: 0.8606 - val_loss: 0.4008
# Epoch 12/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 70s 75ms/step - accuracy: 0.8730 - loss: 0.3554 - val_accuracy: 0.8609 - val_loss: 0.3970
# Epoch 13/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 84s 77ms/step - accuracy: 0.8748 - loss: 0.3506 - val_accuracy: 0.8598 - val_loss: 0.3952
# Epoch 14/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 73s 78ms/step - accuracy: 0.8763 - loss: 0.3460 - val_accuracy: 0.8620 - val_loss: 0.3931
# Epoch 15/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 78ms/step - accuracy: 0.8776 - loss: 0.3418 - val_accuracy: 0.8636 - val_loss: 0.3881
# Epoch 16/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 74s 79ms/step - accuracy: 0.8792 - loss: 0.3376 - val_accuracy: 0.8619 - val_loss: 0.3919
# Epoch 17/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 81s 78ms/step - accuracy: 0.8807 - loss: 0.3345 - val_accuracy: 0.8634 - val_loss: 0.3845
# Epoch 18/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 71s 75ms/step - accuracy: 0.8819 - loss: 0.3306 - val_accuracy: 0.8644 - val_loss: 0.3849
# Epoch 19/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 84s 77ms/step - accuracy: 0.8824 - loss: 0.3281 - val_accuracy: 0.8643 - val_loss: 0.3853
# Epoch 20/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 74s 78ms/step - accuracy: 0.8836 - loss: 0.3251 - val_accuracy: 0.8647 - val_loss: 0.3832
# Epoch 21/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 71s 76ms/step - accuracy: 0.8843 - loss: 0.3222 - val_accuracy: 0.8648 - val_loss: 0.3832
# Epoch 22/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 84s 78ms/step - accuracy: 0.8853 - loss: 0.3194 - val_accuracy: 0.8658 - val_loss: 0.3810
# Epoch 23/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 81s 77ms/step - accuracy: 0.8866 - loss: 0.3165 - val_accuracy: 0.8659 - val_loss: 0.3819
# Epoch 24/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 70s 75ms/step - accuracy: 0.8872 - loss: 0.3137 - val_accuracy: 0.8671 - val_loss: 0.3789
# Epoch 25/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 71s 75ms/step - accuracy: 0.8880 - loss: 0.3112 - val_accuracy: 0.8669 - val_loss: 0.3793
# Epoch 26/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 84s 77ms/step - accuracy: 0.8891 - loss: 0.3087 - val_accuracy: 0.8675 - val_loss: 0.3795
# Epoch 27/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 73s 78ms/step - accuracy: 0.8904 - loss: 0.3052 - val_accuracy: 0.8668 - val_loss: 0.3828
# Epoch 28/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 73s 78ms/step - accuracy: 0.8911 - loss: 0.3023 - val_accuracy: 0.8673 - val_loss: 0.3787
# Epoch 29/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 71s 76ms/step - accuracy: 0.8921 - loss: 0.2993 - val_accuracy: 0.8692 - val_loss: 0.3774
# Epoch 30/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 81s 76ms/step - accuracy: 0.8928 - loss: 0.2959 - val_accuracy: 0.8694 - val_loss: 0.3763
# Epoch 31/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 70s 75ms/step - accuracy: 0.8949 - loss: 0.2920 - val_accuracy: 0.8707 - val_loss: 0.3715
# Epoch 32/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 85s 78ms/step - accuracy: 0.8958 - loss: 0.2883 - val_accuracy: 0.8715 - val_loss: 0.3705
# Epoch 33/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 78ms/step - accuracy: 0.8985 - loss: 0.2835 - val_accuracy: 0.8719 - val_loss: 0.3678
# Epoch 34/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 79ms/step - accuracy: 0.8990 - loss: 0.2796 - val_accuracy: 0.8716 - val_loss: 0.3631
# Epoch 35/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 71s 76ms/step - accuracy: 0.9007 - loss: 0.2756 - val_accuracy: 0.8743 - val_loss: 0.3618
# Epoch 36/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 84s 78ms/step - accuracy: 0.9013 - loss: 0.2719 - val_accuracy: 0.8715 - val_loss: 0.3659
# Epoch 37/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 78ms/step - accuracy: 0.9030 - loss: 0.2683 - val_accuracy: 0.8717 - val_loss: 0.3664
# Epoch 38/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 72s 77ms/step - accuracy: 0.9045 - loss: 0.2644 - val_accuracy: 0.8765 - val_loss: 0.3554
# Epoch 39/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 84s 79ms/step - accuracy: 0.9055 - loss: 0.2605 - val_accuracy: 0.8801 - val_loss: 0.3468
# Epoch 40/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 73s 78ms/step - accuracy: 0.9064 - loss: 0.2579 - val_accuracy: 0.8800 - val_loss: 0.3486
# Epoch 41/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 81s 77ms/step - accuracy: 0.9077 - loss: 0.2552 - val_accuracy: 0.8799 - val_loss: 0.3436
# Epoch 42/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 71s 75ms/step - accuracy: 0.9089 - loss: 0.2520 - val_accuracy: 0.8783 - val_loss: 0.3487
# Epoch 43/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 74s 79ms/step - accuracy: 0.9093 - loss: 0.2494 - val_accuracy: 0.8811 - val_loss: 0.3405
# Epoch 44/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 71s 75ms/step - accuracy: 0.9099 - loss: 0.2473 - val_accuracy: 0.8785 - val_loss: 0.3519
# Epoch 45/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 85s 79ms/step - accuracy: 0.9119 - loss: 0.2440 - val_accuracy: 0.8808 - val_loss: 0.3424
# Epoch 46/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 78s 75ms/step - accuracy: 0.9117 - loss: 0.2424 - val_accuracy: 0.8835 - val_loss: 0.3408
# Epoch 47/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 76ms/step - accuracy: 0.9128 - loss: 0.2396 - val_accuracy: 0.8806 - val_loss: 0.3456
# Epoch 48/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 77ms/step - accuracy: 0.9135 - loss: 0.2376 - val_accuracy: 0.8829 - val_loss: 0.3455
# Epoch 49/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 78ms/step - accuracy: 0.9143 - loss: 0.2354 - val_accuracy: 0.8827 - val_loss: 0.3453
# Epoch 50/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 79ms/step - accuracy: 0.9158 - loss: 0.2327 - val_accuracy: 0.8816 - val_loss: 0.3523

# %%
def plot_history(history):
    h = history.history
    epochs = range(len(h['loss']))

    plt.subplot(121), plt.plot(epochs, h['loss'], '.-', epochs, h['val_loss'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('loss')
    plt.legend(['Train', 'Validation'])
    plt.subplot(122), plt.plot(epochs, h['accuracy'], '.-',
                               epochs, h['val_accuracy'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('Accuracy')
    plt.legend(['Train', 'Validation'])

    print('Train Acc     ', h['accuracy'][-1])
    print('Validation Acc', h['val_accuracy'][-1])

plot_history(history)
# Out:
# Train Acc      0.9157500267028809
# Validation Acc 0.881600022315979

# %% [markdown]
# As you can see, the classifier suffers from massive overfitting. The validation accuracy is around 88% while the training accuracy is close to 1.

# %% [markdown]
# ### Combat the Overfitting!
#
# Now it is your turn. Use the classifier as a baseline, include some regularization techniques and try to improve the classification performance. You can try any techniques you might see fit, e.g.,
# * Dropout
# * Batch normalization
# * Weight regularization
# * Data augmentation
# * Early stopping
# * Pooling
# * Reducing the number of parameters (the size of the network)
# * ...
#
# There are to objective you shall fulfill in order to successfully complete this homework:
# * The validation accuracy shall be above 91%
# * Your network (with all the regularizations applied) shall **not** be larger than the baseline

# %%
inputs = Input(shape=(28, 28, 1))
net = Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same')(inputs)
net = BatchNormalization()(net)
net = MaxPooling2D((2, 2))(net)
net = Flatten()(net)
net = Dense(128, activation='relu')(net)
net = Dropout(0.5)(net)
outputs = Dense(10, activation='softmax')(net)

model2 = Model(inputs, outputs)
model2.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 28, 28, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 28, 28, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 6272)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       802,944 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 804,682 (3.07 MB)
#  Trainable params: 804,618 (3.07 MB)
#  Non-trainable params: 64 (256.00 B)

# %%
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=5,
    restore_best_weights=True
)

model2.compile(loss='sparse_categorical_crossentropy',
               optimizer='adam',
               metrics=['accuracy'])

history2 = model2.fit(x_train, y_train,
                      batch_size=64,
                      epochs=50,
                      validation_data=(x_test, y_test),
                      callbacks=[early_stop])
# Out:
# Epoch 1/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 67s 69ms/step - accuracy: 0.8362 - loss: 0.4669 - val_accuracy: 0.8788 - val_loss: 0.3287
# Epoch 2/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 60s 64ms/step - accuracy: 0.8846 - loss: 0.3193 - val_accuracy: 0.8970 - val_loss: 0.2751
# Epoch 3/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 66ms/step - accuracy: 0.8961 - loss: 0.2796 - val_accuracy: 0.8961 - val_loss: 0.2924
# Epoch 4/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 59s 63ms/step - accuracy: 0.9069 - loss: 0.2519 - val_accuracy: 0.9046 - val_loss: 0.2706
# Epoch 5/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 63s 67ms/step - accuracy: 0.9142 - loss: 0.2288 - val_accuracy: 0.9050 - val_loss: 0.2718
# Epoch 6/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 60s 64ms/step - accuracy: 0.9214 - loss: 0.2132 - val_accuracy: 0.9069 - val_loss: 0.2693
# Epoch 7/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 61s 65ms/step - accuracy: 0.9251 - loss: 0.1966 - val_accuracy: 0.9087 - val_loss: 0.2669
# Epoch 8/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 81s 63ms/step - accuracy: 0.9291 - loss: 0.1865 - val_accuracy: 0.9091 - val_loss: 0.2794
# Epoch 9/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 60s 64ms/step - accuracy: 0.9339 - loss: 0.1735 - val_accuracy: 0.9103 - val_loss: 0.2831
# Epoch 10/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 84s 66ms/step - accuracy: 0.9388 - loss: 0.1615 - val_accuracy: 0.9095 - val_loss: 0.3010
# Epoch 11/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 81s 65ms/step - accuracy: 0.9416 - loss: 0.1554 - val_accuracy: 0.9102 - val_loss: 0.3134
# Epoch 12/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 61s 65ms/step - accuracy: 0.9432 - loss: 0.1491 - val_accuracy: 0.9103 - val_loss: 0.2928
# Epoch 13/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 64ms/step - accuracy: 0.9468 - loss: 0.1383 - val_accuracy: 0.9119 - val_loss: 0.3197
# Epoch 14/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 81s 63ms/step - accuracy: 0.9481 - loss: 0.1376 - val_accuracy: 0.9107 - val_loss: 0.3393
# Epoch 15/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 65ms/step - accuracy: 0.9512 - loss: 0.1297 - val_accuracy: 0.9092 - val_loss: 0.3698
# Epoch 16/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 63s 67ms/step - accuracy: 0.9531 - loss: 0.1230 - val_accuracy: 0.9085 - val_loss: 0.3356
# Epoch 17/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 62s 66ms/step - accuracy: 0.9531 - loss: 0.1238 - val_accuracy: 0.9108 - val_loss: 0.3665
# Epoch 18/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 60s 64ms/step - accuracy: 0.9559 - loss: 0.1154 - val_accuracy: 0.9115 - val_loss: 0.3580

# %%
# Show the results
def plot_history(history):
    h = history.history
    epochs = range(len(h['loss']))

    plt.subplot(121), plt.plot(epochs, h['loss'], '.-', epochs, h['val_loss'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('loss')
    plt.legend(['Train', 'Validation'])
    plt.subplot(122), plt.plot(epochs, h['accuracy'], '.-',
                               epochs, h['val_accuracy'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('Accuracy')
    plt.legend(['Train', 'Validation'])

    print('Train Acc     ', h['accuracy'][-1])
    print('Validation Acc', h['val_accuracy'][-1])

plot_history(history2)
# Out:
# Train Acc      0.9559000134468079
# Validation Acc 0.9114999771118164

# %% [markdown]
# ### Questions
#
# What have you done in order to improve the performance?
#
# Several regularization techniques were applied to the baseline model:
#
#   - BatchNormalization - added after the convolutional layer to stabilize training and reduce internal covariate shift
#   - MaxPooling - reduces spatial dimensions which decreases the number of parameters compared to the baseline
#   - Dropout(0.5) - randomly disables 50% of neurons in the Dense layer during training to prevent memorization
#   - Early stopping - monitors validation accuracy and stops training when it stops improving, restoring the best weights automatically
#
# Have you tried configurations that did not work out?
#
#  Yes. Using Dropout alone without BatchNormalization reduced overfitting but the validation accuracy stayed below 91%. Adding only BatchNormalization without Dropout also helped but was not enough. The combination of all 4 techniques together gave the best result above 91% validation accuracy.
